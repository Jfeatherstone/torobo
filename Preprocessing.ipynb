# %%
import numpy as np

import matplotlib.pyplot as plt

# %%
circleData = np.load('data/square.npz')

# %%
list(circleData.keys())
# Out:
# ['joint_names', 'positions', 'velocities', 'efforts', 'timestamps', 'fps']

# %%
f = int(circleData["fps"])

# %%
plt.plot(circleData["positions"][:,1], 'o')
plt.show()
